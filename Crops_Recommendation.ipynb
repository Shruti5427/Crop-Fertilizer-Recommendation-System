# %% [markdown]
# #Crop And Fertilizer Recommendation System using ML

# %%
#Importing Necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# crop =  pd.read_csv("Dataset/Crop_recommendation.csv)

# %%
#Reading csv File using Pandas
crop = pd.read_csv("Dataset/Crop_recommendation.csv")

# %%
#Displays the number of rows and columns in the dataset.
crop.shape
# Out:
# (2200, 8)

# %%
#Returns a DataFrame of the same shape with True where values are missing and False otherwise.
crop.isnull()
# Out:
#           N      P      K  temperature  humidity     ph  rainfall  label
# 0     False  False  False        False     False  False     False  False
# 1     False  False  False        False     False  False     False  False
# 2     False  False  False        False     False  False     False  False
# 3     False  False  False        False     False  False     False  False
# 4     False  False  False        False     False  False     False  False
# ...     ...    ...    ...          ...       ...    ...       ...    ...
# 2195  False  False  False        False     False  False     False  False
# 2196  False  False  False        False     False  False     False  False
# 2197  False  False  False        False     False  False     False  False
# 2198  False  False  False        False     False  False     False  False
# 2199  False  False  False        False     False  False     False  False
#
# [2200 rows x 8 columns]

# %%
# CORRELATION OF THE FEATURES
num_cols = crop.select_dtypes(include=[np.number])
num_cols
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
corr = num_cols.corr()
corr
# Out:
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.231460 -0.140512     0.026504  0.190688  0.096683
# P           -0.231460  1.000000  0.736232    -0.127541 -0.118734 -0.138019
# K           -0.140512  0.736232  1.000000    -0.160387  0.190859 -0.169503
# temperature  0.026504 -0.127541 -0.160387     1.000000  0.205320 -0.017795
# humidity     0.190688 -0.118734  0.190859     0.205320  1.000000 -0.008483
# ph           0.096683 -0.138019 -0.169503    -0.017795 -0.008483  1.000000
# rainfall     0.059020 -0.063839 -0.053461    -0.030084  0.094423 -0.109069
#
#              rainfall
# N            0.059020
# P           -0.063839
# K           -0.053461
# temperature -0.030084
# humidity     0.094423
# ph          -0.109069
# rainfall     1.000000

# %% [markdown]
# #Improvised Code

# %%
# Display basic dataset information
display(crop.head(), crop.tail())  # Using display() for better output readability
print("\nDataset Shape:", crop.shape)
print("\nDataset Info:")
crop.info()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
# Dataset Shape: (2200, 8)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# ...

# %%
# Check for missing values
print("\nMissing Values per Column:\n", crop.isnull().sum())
# Out:
# Missing Values per Column:
#  N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
# Check for duplicates
duplicate_count = crop.duplicated().sum()
print(f"\nNumber of Duplicated Rows: {duplicate_count}")
# Out:
# Number of Duplicated Rows: 0

# %%
# Display summary statistics
print("\nSummary Statistics:")
display(crop.describe())
# Out:
# Summary Statistics:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
# Show column names
print("\nColumn Names:", crop.columns.tolist())
# Out:
# Column Names: ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label']

# %%
# Display class distribution
print("\nCrop Label Distribution:")
display(crop['label'].value_counts())
# Out:
# Crop Label Distribution:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
# Function to extract feature columns
def get_features(df, target_column='label'):
    return [col for col in df.columns if col != target_column]
features = get_features(crop)
print("\nFeature Columns:", features)
# Out:
# Feature Columns: ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

# %%
# Visualizing Histograms for each feature
fig, ax = plt.subplots(3, 3, figsize=(15, 15))
for i, subplot in zip(features, ax.flatten()):
    sns.histplot(crop[i], ax=subplot, kde=True, bins=30)
    subplot.set_title(f"Distribution of {i}")
plt.tight_layout()
plt.show()

# %%
# Convert categorical label into numeric values for visualization

crop_dict = {label: idx for idx, label in enumerate(crop['label'].unique())}  # Create mapping dictionary
crop['crop_no'] = crop['label'].map(crop_dict)  # Apply mapping

# %%
# Scatter Plots: Feature vs Crop Type
fig, ax = plt.subplots(3, 3, figsize=(15, 15))
for i, subplot in zip(features, ax.flatten()):
    sns.scatterplot(x=crop[i], y=crop['crop_no'], ax=subplot)
    subplot.set_title(f"Scatter Plot: {i} vs Crop Type")
plt.tight_layout()
plt.show()

# %%
# Boxplot Visualization for Outlier Detection
fig, ax = plt.subplots(3, 3, figsize=(15, 15))
for i, subplot in zip(features, ax.flatten()):
    sns.boxplot(x=crop[i], ax=subplot)  # Fixed syntax issue
    subplot.set_title(f"Box Plot of {i}")
plt.tight_layout()
plt.show()

# %%
# Compute correlation matrix for numerical columns
num_cols = crop.select_dtypes(include=[np.number])
corr = num_cols.corr()

# %%
# Display correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
print("\nUnique Crop Labels:", crop['label'].unique())
# Out:
# Unique Crop Labels: ['rice' 'maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans'
#  'mungbean' 'blackgram' 'lentil' 'pomegranate' 'banana' 'mango' 'grapes'
#  'watermelon' 'muskmelon' 'apple' 'orange' 'papaya' 'coconut' 'cotton'
#  'jute' 'coffee']

# %%
# Drop the original label column after encoding
crop.drop('label', axis=1, inplace=True)
print("\nFinal DataFrame Preview:")
display(crop.head())
# Out:
# Final DataFrame Preview:
#     N   P   K  temperature   humidity        ph    rainfall  crop_no
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536        0
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537        0
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248        0
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034        0
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340        0
